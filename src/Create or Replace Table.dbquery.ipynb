-- %%
create schema if not exists bronze;

create or replace table bronze.sales_customer
as
select * from samples.bakehouse.sales_franchises
where 1 = 0


--drop table workspace.bronze.sales_customers

DROP SCHEMA bronze_dev
