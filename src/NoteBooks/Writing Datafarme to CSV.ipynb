# %%
path = "/Volumes/population_metrics/landing/datasets/countries_dataset/csv_data/countries_population/countries_population.csv"

df = spark.read.format("csv").options(header="true", inferSchema="true").load(path)

df.display()

# %%
output_pacth = "/Volumes/population_metrics/landing/datasets/output_dataset/csv/countries_population"

# %%
df.write.mode("overwrite").option("header", "true").csv(output_pacth)

# %%
df.write.format("csv").mode("overwrite").options(header="true", sep="|").save(output_pacth)
