# %%
path = "/Volumes/population_metrics/landing/datasets/countries_dataset/csv_data/countries_population/countries_population.csv"

# %%
df = spark.read.format("csv").schema("COUNTRY_ID int, NAME string, NATIONALITY string, COUNTRY_CODE string, ISO_ALPHA2 string, CAPITAL string, POPULATION int, AREA_SQ_MI int, POP_DENSITY string, COASTLINE_RATIO string, NET_MIGRATION string").option("header", "true").load(path)

df.display()
