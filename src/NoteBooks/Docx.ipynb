# %%
/Volumes/books/default/book_test/Cronicas de Ælagar Omega v3 d2d.docxdf = spark.table("books.information_schema.volumes")
display(df.select("volume_name", "volume_type", "comment", "created", "last_altered"))
